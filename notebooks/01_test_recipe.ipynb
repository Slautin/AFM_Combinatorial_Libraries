# %%
from afm_lib.schemas.recipe import load_recipe

recipe = load_recipe("../recipes/smoke_2site.yaml")
print(recipe.name, "-", len(recipe.sites), "sites,",
      len(recipe.per_site[0].points_m), "points/site")
for s in recipe.sites:
    print(f"  {s.label}: ({s.x_stage_m*1e3:+.3f}, {s.y_stage_m*1e3:+.3f}) mm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from afm_lib.schemas.recipe import load_recipe
#       3 recipe = load_recipe("../recipes/smoke_2site.yaml")
#       4 print(recipe.name, "-", len(recipe.sites), "sites,",
#       5       len(recipe.per_site[0].points_m), "points/site")
#
# File ~\Documents\GitHub\AFM_Combinatorial_Libraries\src\afm_lib\schemas\recipe.py:7
#       4 import yaml
#       5 from pydantic import BaseModel, Field
# ----> 7 from afm_lib.schemas.instrument import LoopSettings
#      10 class SiteSpec(BaseModel, frozen=True):
#      11     label: str
#
# File ~\Documents\GitHub\AFM_Combinatorial_Libraries\src\afm_lib\schemas\instrument.py:2
#       1 from pydantic import BaseModel, Field
# ----> 2 from spm_agent.schemas.scanner_calibrations import ScannerCalibrations
#       6 class ScanSettings(BaseModel, frozen=True):
#       7     """Geometry and acquisition properties of the scan frame."""
#
# ModuleNotFoundError: No module named 'spm_agent'

# %%
from afm_lib.schemas.recipe import load_recipe
from afm_lib.schemas.instrument import to_instrument_state
from afm_lib.instrument.session import call

recipe = load_recipe("../recipes/smoke_2site.yaml")
print(recipe.name, len(recipe.sites), "sites")

raw = await call("pfm_get_experiment_status")
live = to_instrument_state(raw, scanner_calibrations=None)
print(live.stage_position)          # the field that must not be None
print(live.probe_position)          # None before calibration — expected
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from afm_lib.schemas.recipe import load_recipe
#       2 from afm_lib.schemas.instrument import to_instrument_state
#       3 from afm_lib.instrument.session import call
#
# ModuleNotFoundError: No module named 'afm_lib.schemas.recipe'
